# %% [markdown]
# # 1.Importing Libraries

# %%
#importing Required library 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#importing plotly Library
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf
py.offline.init_notebook_mode(connected=True) #Turning on notebook mode 
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
# ...

# %% [markdown]
# # 2.Load dataset

# %%
df = pd.read_csv(r"C:\Users\pc\Downloads\Automobile_data.csv")
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# # 3. Basic Data Exploration

# %%
df.shape
# Out:
# (205, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %% [markdown]
# # 4. Handling Missing and Duplicate Values

# %%
df_data = df.replace('?',np.NAN) 
df_data.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
# Duplicates values
df_data.duplicated().sum()
# Out:
# 0

# %%
df_data
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
sns.heatmap(df_data.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
#df_data["normalized-losses"].fillna(value=df_data["normalized-losses"].mean())
#df

df1 = df[df['normalized-losses']!='?']
mean_value = df1['normalized-losses'].astype(int).mean()
df['normalized-losses'] = df['normalized-losses'].replace('?',mean_value).astype(int)

df['normalized-losses']
# Out:
# 0      122
# 1      122
# 2      122
# 3      164
# 4      164
#       ...
# 200     95
# 201     95
# 202     95
# 203     95
# 204     95
# Name: normalized-losses, Length: 205, dtype: int32

# %%
df_data = df.replace('?',np.NAN) 
df_data.isnull().sum()
#df_data
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
sns.heatmap(df_data.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
df_data.dropna(how='any',inplace=True)

# %%
#df_data = df_data.replace('?',np.NAN) 
df_data.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          193 non-null    int64
#  1   normalized-losses  193 non-null    int32
#  2   make               193 non-null    object
#  3   fuel-type          193 non-null    object
#  4   aspiration         193 non-null    object
#  5   num-of-doors       193 non-null    object
#  6   body-style         193 non-null    object
#  7   drive-wheels       193 non-null    object
#  8   engine-location    193 non-null    object
#  9   wheel-base         193 non-null    float64
#  10  length             193 non-null    float64
#  11  width              193 non-null    float64
#  12  height             193 non-null    float64
#  13  curb-weight        193 non-null    int64
#  14  engine-type        193 non-null    object
#  15  num-of-cylinders   193 non-null    object
# ...

# %% [markdown]
# # Convert Pice datatype

# %%
df_data.price = df_data.price.str.strip().astype('float')

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          193 non-null    int64
#  1   normalized-losses  193 non-null    int32
#  2   make               193 non-null    object
#  3   fuel-type          193 non-null    object
#  4   aspiration         193 non-null    object
#  5   num-of-doors       193 non-null    object
#  6   body-style         193 non-null    object
#  7   drive-wheels       193 non-null    object
#  8   engine-location    193 non-null    object
#  9   wheel-base         193 non-null    float64
#  10  length             193 non-null    float64
#  11  width              193 non-null    float64
#  12  height             193 non-null    float64
#  13  curb-weight        193 non-null    int64
#  14  engine-type        193 non-null    object
#  15  num-of-cylinders   193 non-null    object
# ...

# %%
sns.heatmap(df_data.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
df_data.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df_data.shape
# Out:
# (193, 26)

# %%
df_data.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  193.000000         193.000000  193.000000  193.000000  193.000000
# mean     0.797927         121.284974   98.923834  174.326425   65.893782
# std      1.235582          32.342674    6.152409   12.478593    2.137795
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000          95.000000   94.500000  166.300000   64.100000
# 50%      1.000000         122.000000   97.000000  173.200000   65.400000
# 75%      2.000000         134.000000  102.400000  184.600000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.000000
#
#            height  curb-weight  engine-size  compression-ratio    city-mpg  \
# count  193.000000   193.000000   193.000000         193.000000  193.000000
# mean    53.869948  2561.507772   128.124352          10.143627   25.326425
# std      2.394770   526.700026    41.590452           3.977491    6.387828
# ...

# %% [markdown]
# # Rename Column Names

# %%
#Changing the column names
df_data = df_data.rename(columns={'make':'company','num-of-doors':'doors_no','body-style':'body_style','drive-wheels':'drive_wheels',
                                 'engine-location':'engine_location','wheel-base':'wheel_base','fuel-type':'fuel_type'})
df_data.columns
# Out:
# Index(['symboling', 'normalized-losses', 'company', 'fuel_type', 'aspiration',
#        'doors_no', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %% [markdown]
# # 5.Data Analysis

# %%
df_data.doors_no.value_counts().plot.pie(fontsize = 18, autopct = '%.2f')
# Out:
# <AxesSubplot:ylabel='doors_no'>

# %% [markdown]
# 58.03 % cars have 4 doors and
# 41.97 % cars have 2 doors

# %%
df_data.fuel_type.value_counts().plot.pie(fontsize = 18, autopct = '%.2f')
# Out:
# <AxesSubplot:ylabel='fuel_type'>

# %% [markdown]
# More than 90% cars are run on gas Fuel.

# %%
df_data.body_style.value_counts().plot.pie(fontsize = 18, autopct = '%.2f')
# Out:
# <AxesSubplot:ylabel='body_style'>

# %% [markdown]
# Most of the times sedan type body style is used followed by hatchback.

# %%
cat_cols = ['drive_wheels','engine_location','engine-type','num-of-cylinders', 'fuel-system','drive_wheels']
i=0
while i < 6:
    fig = plt.figure(figsize=[20,5])
    
    
    
    plt.subplot(1,2,1)
    sns.countplot(x=cat_cols[i], data=df_data)
    plt.xticks(rotation=45)
    i += 1
    
    
    plt.subplot(1,2,2)
    sns.countplot(x=cat_cols[i], data=df_data)
    plt.xticks(rotation=90)
    i += 1
    
    plt.show()

# %% [markdown]
# More than 70 % of the vehicle has Ohc type of Engine
#
# 57% of the cars has 4 doors
#
# Gas is preferred by 85 % of the vehicles
#
# Most produced vehicle are of body style sedan around 48% followed by hatchback 32%

# %%
import seaborn as sns
corr = df_data.corr()
plt.figure(figsize=(20,9))
a = sns.heatmap(corr, annot=True, fmt='.2f')

# %% [markdown]
# curb-size, engine-size are positively correlated
#
# city-mpg,highway-mpg are highly positive correlated
#
# curb_weight and city-mpg,highway-mpg are negatively correlated
#
# length and width with city-mpg,highway-mpg are also negatively correlated

# %% [markdown]
# # Price Analysis

# %%
sns.catplot(data=df_data, x="body_style", y="price" ,kind="bar")

# %% [markdown]
# convertible and Hardtop body styles are more expensive than other styles

# %%
g = sns.pairplot(df_data[["city-mpg", "engine-size", "curb-weight","price","fuel_type"]], hue="fuel_type", diag_kind="hist")

# %% [markdown]
# city mpg decrease as increase in engine-size, Curb Weight and price.
#
#
# Curbweight increases with the increase in Engine Size, price. It is somewhat exponential nature.

# %%
ex=df_data.groupby('body_style')['price'].mean().reset_index()
ex
# Out:
#     body_style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9763.984127
# 3        sedan  14563.739130
# 4        wagon  12500.166667

# %%
sns.catplot(data=ex, x="body_style", y="price" ,kind="bar")

# %%
fig = plt.figure(figsize=[20,10])
sns.boxplot(x="company", y="price", data=df_data)
# Out:
# <AxesSubplot:xlabel='company', ylabel='price'>

# %%
sns.boxplot(x="drive_wheels", y="price", data=df_data)
# Out:
# <AxesSubplot:xlabel='drive_wheels', ylabel='price'>

# %%
fig = plt.figure(figsize=[20,5])
sns.catplot(data=df_data, x="peak-rpm", y="price" ,kind="point")

# %% [markdown]
# Mercedez-Benz ,BMW, Jaguar, Porshe produces expensive cars more than 25000.
#
# cheverolet,dodge, honda,mitbushi, nissan,plymouth subaru,toyata have relatively lower prices.
#
# most of the cars comapany produces car in range below 25000
#
# Hardtop model are expensive in prices followed by convertible and sedan body style
#
# hatchback and sedan models are available below 20000
#
# rwd wheel drive vehicle have expensive prices

# %%
sns.regplot(x= "city-mpg", y= 'price', data=df_data)
# Out:
# <AxesSubplot:xlabel='city-mpg', ylabel='price'>

# %% [markdown]
# Fuel Efficiency has a negatiVe correlation with price.

# %%
sns.regplot(x= "city-mpg", y= 'highway-mpg', data=df_data)
# Out:
# <AxesSubplot:xlabel='city-mpg', ylabel='highway-mpg'>

# %% [markdown]
# city-mpg and highway-mpg are strongly correlated.
